# %%
x<-rnorm(10)

# %%
x
# Out:
#  [1]  0.07213423  1.05343374 -0.24580504  2.22508464 -0.81590578 -1.37222081
#  [7]  1.80538600  0.07836272  1.56609604 -1.48602320

# %%
x<-rnorm(10,mean=0,sd=1)

# %%
x
# Out:
#  [1] -2.44862789 -0.62564348 -0.11389066  1.19888568 -0.53923887 -2.26061840
#  [7]  0.33964247  1.15138174  2.15599857  0.02144108

# %%
x<-rnorm(10,mean=20,sd=1)

# %%
x
# Out:
#  [1] 19.35336 20.75384 20.69183 20.57876 21.51823 19.66900 19.77804 18.01489
#  [9] 20.74166 22.07103
